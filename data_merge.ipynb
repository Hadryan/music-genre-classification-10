# %%
import pandas as pd

# %%
tracks = pd.read_csv('./data/final_tracks.csv')
features = pd.read_csv('./data/features.csv')

# %%
tracks.head()
# Out:
#    track_id         genre                            title
# 0    135054  Experimental  Hari Karl (for Larry Eisenberg)
# 1    135336           Pop                  Slow and Steady
# 2    135337           Pop        The Dream and the Dreamer
# 3    135043          Folk                            Babel
# 4    135091  Experimental                    Tree and Wind

# %%
merged_df = tracks.merge(features, how = 'inner', right_on = 'track_id', left_on = 'track_id')
merged_df.head()
# Out:
#    track_id         genre                            title feature  \
# 0    135054  Experimental  Hari Karl (for Larry Eisenberg)       0
# 1    135336           Pop                  Slow and Steady       1
# 2    135337           Pop        The Dream and the Dreamer       2
# 3    135043          Folk                            Babel       3
# 4    135091  Experimental                    Tree and Wind       4
#
#    chroma_cens  chroma_cens.1  chroma_cens.2  chroma_cens.3  chroma_cens.4  \
# 0     0.310373       0.308683       0.290821       0.297749       0.287629
# 1     0.161290       0.161296       0.190398       0.171992       0.189878
# 2     0.443386       0.357355       0.191626       0.202726       0.284854
# 3     0.141946       0.153972       0.169128       0.218597       0.385648
# 4     0.017648       0.017463       0.035690       0.158926       0.163426
#
#    chroma_cens.5  ...  spectral_contrast.5  spectral_contrast.6  \
# ...

# %%
merged_df.to_csv('./data/merged_data.csv')
